# %% [markdown]
# # HTML Scrapper

# %% [markdown]
# ## Intención de este notebook

# %% [markdown]
# Parsear los archvios HTML entregados por la cátedra, para así obtener la información importante de cada vuelo.

# %% [markdown]
# ## Importación de librerías

# %%
from bs4 import BeautifulSoup
import pandas as pd
import os

# %% [markdown]
# ## Análisis previo

# %%
f = open("C:/Users/rodri/OneDrive/Documentos/html files/AA+ABE+CLT.html", encoding='utf-8')
soup = BeautifulSoup(f)
f.close()

# %% [markdown]
# ### Aerolínea y número de vuelo

# %%
def get_vuelo(soup):
    a = []
    contentTable  = soup.find_all('div', { "class" : "ZCLkpe"})
    for x in contentTable:
        a.append([x.text])
    return a

get_vuelo(soup)
# Out:
# [[' American   \xa0– AA 5105  '],
#  [' American   \xa0– AA 5314  '],
#  [' American   \xa0– AA 5231  '],
#  [' American   \xa0– AA 5105  '],
#  [' American   \xa0– AA 5314  '],
#  [' American   \xa0– AA 5231  '],
#  [' American   \xa0– AA 5105  '],
#  [' American   \xa0– AA 5314  '],
#  [' American   \xa0– AA 5231  '],
#  [' American   \xa0– AA 5105  '],
#  [' American   \xa0– AA 5314  '],
#  [' American   \xa0– AA 5231  ']]

# %% [markdown]
# ### Horarios y puertas de embarque

# %%
def get_horarios(soup):
    r = []
    d = soup.find_all('tr', class_ ="kWOKDd")
    for i in range(0, len(d), 2):
        r.append(d[i:i+2][1].text.split())
    return r

get_horarios(soup)
# Out:
# [['06:03', '-', '11', '08:58', '-', 'E11'],
#  ['11:26', '-', '-', '13:31', '-', 'E11'],
#  ['18:43', '-', '11', '20:55', '-', 'E20'],
#  ['06:07', '-', '11', '08:31', '-', 'E20'],
#  ['11:37', '-', '-', '13:44', '-', 'E11'],
#  ['18:50', '-', '-', '21:00', '-', 'E20'],
#  ['06:12', '-', '-', '08:24', '-', 'E15'],
#  ['11:37', '-', '-', '13:44', '-', 'E11'],
#  ['18:50', '-', '-', '21:00', '-', 'E30'],
#  ['06:12', '-', '-', '08:24', '-', '-'],
#  ['11:37', '-', '-', '13:44', '-', '-'],
#  ['18:50', '-', '-', '21:00', '-', '-']]

# %% [markdown]
# ### Días de salida y llegada

# %%
#Inicio --- Llegada
def get_inicio_llegada(soup):
    il = []
    d = soup.find_all('th', class_ ="a48lTe")
    for i in range(0, len(d), 2):
        il.append([d[i:i+2][0].text, d[i:i+2][1].text])
    return il

get_inicio_llegada(soup)
# Out:
# [['  Allentown  · jue., 7 de marzo   ', '  Charlotte  · jue., 7 de marzo   '],
#  ['  Allentown  · jue., 7 de marzo   ', '  Charlotte  · jue., 7 de marzo   '],
#  ['  Allentown  · jue., 7 de marzo   ', '  Charlotte  · jue., 7 de marzo   '],
#  ['  Allentown  · vie., 8 de marzo   ', '  Charlotte  · vie., 8 de marzo   '],
#  ['  Allentown  · vie., 8 de marzo   ', '  Charlotte  · vie., 8 de marzo   '],
#  ['  Allentown  · vie., 8 de marzo   ', '  Charlotte  · vie., 8 de marzo   '],
#  ['  Allentown  · sáb., 9 de marzo   ', '  Charlotte  · sáb., 9 de marzo   '],
#  ['  Allentown  · sáb., 9 de marzo   ', '  Charlotte  · sáb., 9 de marzo   '],
#  ['  Allentown  · sáb., 9 de marzo   ', '  Charlotte  · sáb., 9 de marzo   '],
#  ['  Allentown  · dom., 10 de marzo   ',
#   '  Charlotte  · dom., 10 de marzo   '],
#  ['  Allentown  · dom., 10 de marzo   ',
#   '  Charlotte  · dom., 10 de marzo   '],
#  ['  Allentown  · dom., 10 de marzo   ',
#   '  Charlotte  · dom., 10 de marzo   ']]

# %% [markdown]
# Comprobamos que no se perdió ningún registro

# %%
len(get_vuelo(soup)) == len(get_horarios(soup)) == len(get_inicio_llegada(soup))
# Out:
# True

# %% [markdown]
# Concatenamos la información obtenida

# %%
v = get_vuelo(soup)
h = get_horarios(soup)
il = get_inicio_llegada(soup)

data = []
for i in range(0, len(v)):
    data.append(v[i]+h[i]+il[i])

# %% [markdown]
# ### Dataframe de ejemplo

# %%
columnas = ['aerolinea', 'horario_salida', 'terminal_salida', 'puerta_salida',
            'horario_llegada', 'terminal_llegada', 'puerta_llegada', 'origen', 'destino']
pd.DataFrame(data, columns=columnas)
# Out:
#                    aerolinea horario_salida terminal_salida puerta_salida  \
# 0    American    – AA 5105            06:03               -            11
# 1    American    – AA 5314            11:26               -             -
# 2    American    – AA 5231            18:43               -            11
# 3    American    – AA 5105            06:07               -            11
# 4    American    – AA 5314            11:37               -             -
# 5    American    – AA 5231            18:50               -             -
# 6    American    – AA 5105            06:12               -             -
# 7    American    – AA 5314            11:37               -             -
# 8    American    – AA 5231            18:50               -             -
# 9    American    – AA 5105            06:12               -             -
# 10   American    – AA 5314            11:37               -             -
# 11   American    – AA 5231            18:50               -             -
#
#    horario_llegada terminal_llegada puerta_llegada  \
# 0            08:58                -            E11
# 1            13:31                -            E11
# 2            20:55                -            E20
# 3            08:31                -            E20
# 4            13:44                -            E11
# 5            21:00                -            E20
# 6            08:24                -            E15
# 7            13:44                -            E11
# 8            21:00                -            E30
# 9            08:24                -              -
# 10           13:44                -              -
# 11           21:00                -              -
#
#                                  origen                              destino
# 0      Allentown  · jue., 7 de marzo        Charlotte  · jue., 7 de marzo
# 1      Allentown  · jue., 7 de marzo        Charlotte  · jue., 7 de marzo
# 2      Allentown  · jue., 7 de marzo        Charlotte  · jue., 7 de marzo
# 3      Allentown  · vie., 8 de marzo        Charlotte  · vie., 8 de marzo
# 4      Allentown  · vie., 8 de marzo        Charlotte  · vie., 8 de marzo
# 5      Allentown  · vie., 8 de marzo        Charlotte  · vie., 8 de marzo
# 6      Allentown  · sáb., 9 de marzo        Charlotte  · sáb., 9 de marzo
# 7      Allentown  · sáb., 9 de marzo        Charlotte  · sáb., 9 de marzo
# 8      Allentown  · sáb., 9 de marzo        Charlotte  · sáb., 9 de marzo
# 9     Allentown  · dom., 10 de marzo       Charlotte  · dom., 10 de marzo
# 10    Allentown  · dom., 10 de marzo       Charlotte  · dom., 10 de marzo
# 11    Allentown  · dom., 10 de marzo       Charlotte  · dom., 10 de marzo

# %% [markdown]
# ## Función completa para scrappear cada link HTML

# %%
# Aerolinea y numero de vuelo
def get_vuelo(soup):
    a = []
    contentTable  = soup.find_all('div', { "class" : "ZCLkpe"})
    for x in contentTable:
        a.append([x.text])
    return a

# Horarios y puertas de embarque
def get_horarios(soup):
    r = []
    d = soup.find_all('tr', class_ ="kWOKDd")
    for i in range(0, len(d), 2):
        r.append(d[i:i+2][1].text.split())
    return r

# Dias de inicio y llegada
def get_inicio_llegada(soup):
    il = []
    d = soup.find_all('th', class_ ="a48lTe")
    for i in range(0, len(d), 2):
        il.append([d[i:i+2][0].text, d[i:i+2][1].text])
    return il

# Funcion completa
def scrapeo_vuelo(path):
    f = open(path, encoding='utf-8')
    soup = BeautifulSoup(f)
    f.close()

    v = get_vuelo(soup)
    h = get_horarios(soup)
    il = get_inicio_llegada(soup)
    data = []

    if (len(v) == len(h) == len(il)):
        for i in range(0, len(v)):
            data.append(v[i]+h[i]+il[i])
    return data

# %% [markdown]
# ### Ejemplo 1

# %%
scrapeo_vuelo('C:/Users/rodri/OneDrive/Documentos/html files/A9+AMS+TBS.html')
# Out:
# [[' Georgian Airways   \xa0– A9 652  ',
#   '19:00',
#   '-',
#   '-',
#   '02:30',
#   '-',
#   '-',
#   '  Ámsterdam  · jue., 7 de marzo   ',
#   '  Tiflis  · vie., 8 de marzo   '],
#  [' Georgian Airways   \xa0– A9 652  ',
#   '10:20',
#   '-',
#   '-',
#   '17:50',
#   '-',
#   '-',
#   '  Ámsterdam  · sáb., 9 de marzo   ',
#   '  Tiflis  · sáb., 9 de marzo   ']]

# %% [markdown]
# ### Ejemplo 2

# %%
scrapeo_vuelo('C:/Users/rodri/OneDrive/Documentos/html files/AA+ABE+CLT.html')
# Out:
# [[' American   \xa0– AA 5105  ',
#   '06:03',
#   '-',
#   '11',
#   '08:58',
#   '-',
#   'E11',
#   '  Allentown  · jue., 7 de marzo   ',
#   '  Charlotte  · jue., 7 de marzo   '],
#  [' American   \xa0– AA 5314  ',
#   '11:26',
#   '-',
#   '-',
#   '13:31',
#   '-',
#   'E11',
#   '  Allentown  · jue., 7 de marzo   ',
#   '  Charlotte  · jue., 7 de marzo   '],
#  [' American   \xa0– AA 5231  ',
#   '18:43',
#   '-',
#   '11',
#   '20:55',
#   '-',
#   'E20',
#   '  Allentown  · jue., 7 de marzo   ',
#   '  Charlotte  · jue., 7 de marzo   '],
#  [' American   \xa0– AA 5105  ',
#   '06:07',
#   '-',
#   '11',
#   '08:31',
#   '-',
#   'E20',
#   '  Allentown  · vie., 8 de marzo   ',
#   '  Charlotte  · vie., 8 de marzo   '],
#  [' American   \xa0– AA 5314  ',
#   '11:37',
#   '-',
#   '-',
#   '13:44',
#   '-',
#   'E11',
#   '  Allentown  · vie., 8 de marzo   ',
#   '  Charlotte  · vie., 8 de marzo   '],
#  [' American   \xa0– AA 5231  ',
#   '18:50',
#   '-',
#   '-',
#   '21:00',
#   '-',
#   'E20',
#   '  Allentown  · vie., 8 de marzo   ',
#   '  Charlotte  · vie., 8 de marzo   '],
#  [' American   \xa0– AA 5105  ',
#   '06:12',
#   '-',
#   '-',
#   '08:24',
#   '-',
#   'E15',
#   '  Allentown  · sáb., 9 de marzo   ',
#   '  Charlotte  · sáb., 9 de marzo   '],
#  [' American   \xa0– AA 5314  ',
#   '11:37',
#   '-',
#   '-',
#   '13:44',
#   '-',
#   'E11',
#   '  Allentown  · sáb., 9 de marzo   ',
#   '  Charlotte  · sáb., 9 de marzo   '],
#  [' American   \xa0– AA 5231  ',
#   '18:50',
#   '-',
#   '-',
#   '21:00',
#   '-',
#   'E30',
#   '  Allentown  · sáb., 9 de marzo   ',
#   '  Charlotte  · sáb., 9 de marzo   '],
#  [' American   \xa0– AA 5105  ',
#   '06:12',
#   '-',
#   '-',
#   '08:24',
#   '-',
#   '-',
#   '  Allentown  · dom., 10 de marzo   ',
#   '  Charlotte  · dom., 10 de marzo   '],
#  [' American   \xa0– AA 5314  ',
#   '11:37',
#   '-',
#   '-',
#   '13:44',
#   '-',
#   '-',
#   '  Allentown  · dom., 10 de marzo   ',
#   '  Charlotte  · dom., 10 de marzo   '],
#  [' American   \xa0– AA 5231  ',
#   '18:50',
#   '-',
#   '-',
#   '21:00',
#   '-',
#   '-',
#   '  Allentown  · dom., 10 de marzo   ',
#   '  Charlotte  · dom., 10 de marzo   ']]

# %% [markdown]
# ### Ejemplo 3 (con dataframe)

# %%
columnas = ['aerolinea', 'horario_salida', 'terminal_salida', 'puerta_salida',
            'horario_llegada', 'terminal_llegada', 'puerta_llegada', 'origen', 'destino']

data = scrapeo_vuelo('C:/Users/rodri/OneDrive/Documentos/A9+AMS+TBS.html') + \
       scrapeo_vuelo('C:/Users/rodri/OneDrive/Documentos/AA+ABE+CLT.html')

pd.DataFrame(data, columns=columnas)
# Out:
#                           aerolinea horario_salida terminal_salida  \
# 0    Georgian Airways    – A9 652            19:00               -
# 1    Georgian Airways    – A9 652            10:20               -
# 2           American    – AA 5105            06:03               -
# 3           American    – AA 5314            11:26               -
# 4           American    – AA 5231            18:43               -
# 5           American    – AA 5105            06:07               -
# 6           American    – AA 5314            11:37               -
# 7           American    – AA 5231            18:50               -
# 8           American    – AA 5105            06:12               -
# 9           American    – AA 5314            11:37               -
# 10          American    – AA 5231            18:50               -
# 11          American    – AA 5105            06:12               -
# 12          American    – AA 5314            11:37               -
# 13          American    – AA 5231            18:50               -
#
#    puerta_salida horario_llegada terminal_llegada puerta_llegada  \
# 0              -           02:30                -              -
# 1              -           17:50                -              -
# 2             11           08:58                -            E11
# 3              -           13:31                -            E11
# 4             11           20:55                -            E20
# 5             11           08:31                -            E20
# 6              -           13:44                -            E11
# 7              -           21:00                -            E20
# 8              -           08:24                -            E15
# 9              -           13:44                -            E11
# 10             -           21:00                -            E30
# 11             -           08:24                -              -
# 12             -           13:44                -              -
# 13             -           21:00                -              -
#
#                                  origen                              destino
# 0      Ámsterdam  · jue., 7 de marzo           Tiflis  · vie., 8 de marzo
# 1      Ámsterdam  · sáb., 9 de marzo           Tiflis  · sáb., 9 de marzo
# 2      Allentown  · jue., 7 de marzo        Charlotte  · jue., 7 de marzo
# 3      Allentown  · jue., 7 de marzo        Charlotte  · jue., 7 de marzo
# 4      Allentown  · jue., 7 de marzo        Charlotte  · jue., 7 de marzo
# 5      Allentown  · vie., 8 de marzo        Charlotte  · vie., 8 de marzo
# 6      Allentown  · vie., 8 de marzo        Charlotte  · vie., 8 de marzo
# 7      Allentown  · vie., 8 de marzo        Charlotte  · vie., 8 de marzo
# 8      Allentown  · sáb., 9 de marzo        Charlotte  · sáb., 9 de marzo
# 9      Allentown  · sáb., 9 de marzo        Charlotte  · sáb., 9 de marzo
# 10     Allentown  · sáb., 9 de marzo        Charlotte  · sáb., 9 de marzo
# 11    Allentown  · dom., 10 de marzo       Charlotte  · dom., 10 de marzo
# 12    Allentown  · dom., 10 de marzo       Charlotte  · dom., 10 de marzo
# 13    Allentown  · dom., 10 de marzo       Charlotte  · dom., 10 de marzo

# %% [markdown]
# ## Scrapper de todos los links HTML

# %%
entries = os.listdir('/Users/rodri/OneDrive/Documentos/html files/')
path_carpeta = '/Users/rodri/OneDrive/Documentos/html files/'

html_vacios = 0
html_buenos = 0

data2 = []

for i in entries:
    try:
        r = scrapeo_vuelo(path_carpeta + i)
        if r:
            data2 += r
            html_buenos += 1
        else:
            html_vacios += 1
    except:
        print("Fallo en url: {}".format(path_carpeta + i))
        
print("Archivos html buenos: {}".format(html_buenos))
print("--------------------------------------------")
print("Archivos html vacios: {}".format(html_vacios))
# Out:
# Fallo en url: /Users/rodri/OneDrive/Documentos/html files/part1.tar.html
# Archviso html buenos: 2864
# --------------------------------------------
# Archviso html vacios: 1386

# %% [markdown]
# ### Exportación de la data a pickle

# %%
r = pd.DataFrame(data2, columns=columnas)
r.to_pickle("/Users/rodri/OneDrive/Documentos/html files/output.pkl")
r
# Out:
#                               aerolinea horario_salida terminal_salida  \
# 0        Georgian Airways    – A9 652            19:00               -
# 1        Georgian Airways    – A9 652            10:20               -
# 2        Georgian Airways    – A9 628            20:20              2D
# 3       Georgian Airways    – A9 1724            23:10               -
# 4       Georgian Airways    – A9 1724            23:10               -
# 5        Georgian Airways    – A9 651            06:30               -
# 6        Georgian Airways    – A9 627            17:25               -
# 7       Georgian Airways    – A9 1725            05:26               -
# 8       Georgian Airways    – A9 1725            05:15               -
# 9        Georgian Airways    – A9 695            07:00               -
# 10       Georgian Airways    – A9 699            20:55               -
# 11       Georgian Airways    – A9 695            07:00               -
# 12       Georgian Airways    – A9 699            20:55               -
# 13       Georgian Airways    – A9 695            07:00               -
# 14       Georgian Airways    – A9 699            20:55               -
# 15       Georgian Airways    – A9 681            16:30               -
# 16       Georgian Airways    – A9 681            16:30               -
# 17       Georgian Airways    – A9 930            08:55               -
# 18       Georgian Airways    – A9 926            16:30               -
# 19       Georgian Airways    – A9 928            17:40               -
# 20       Georgian Airways    – A9 930            08:55               -
# 21       Georgian Airways    – A9 926            12:30               -
# 22       Georgian Airways    – A9 928            17:40               -
# 23       Georgian Airways    – A9 930            08:55               -
# 24       Georgian Airways    – A9 928            17:40               -
# 25       Georgian Airways    – A9 930            08:55               -
# 26       Georgian Airways    – A9 926            12:30               -
# 27       Georgian Airways    – A9 928            17:40               -
# 28       Georgian Airways    – A9 696            08:40               1
# 29       Georgian Airways    – A9 700            22:30               1
# [35461 rows x 9 columns]

# %% [markdown]
# ## Script final

# %%
# Aerolinea y numero de vuelo
def get_vuelo(soup):
    a = []
    contentTable  = soup.find_all('div', { "class" : "ZCLkpe"})
    for x in contentTable:
        a.append([x.text])
    return a

# Horarios y puertas de embarque
def get_horarios(soup):
    r = []
    d = soup.find_all('tr', class_ ="kWOKDd")
    for i in range(0, len(d), 2):
        r.append(d[i:i+2][1].text.split())
    return r

# Dias de inicio y llegada
def get_inicio_llegada(soup):
    il = []
    d = soup.find_all('th', class_ ="a48lTe")
    for i in range(0, len(d), 2):
        il.append([d[i:i+2][0].text, d[i:i+2][1].text])
    return il

# Funcion completa
def scrapeo_vuelo(path):
    f = open(path, encoding='utf-8')
    soup = BeautifulSoup(f)
    f.close()

    v = get_vuelo(soup)
    h = get_horarios(soup)
    il = get_inicio_llegada(soup)
    data = []

    if ( len(v) == len(h) == len(il) ):
        for i in range(0, len(v)):
            r = v[i]+h[i]+il[i]
            if len(r) == 9:
                data.append(r)
    return data

# Scrapper final
def scrapear_html_aviones(path_carpeta):
    entries = os.listdir(path_carpeta)
    
    html_vacios = 0
    html_buenos = 0
    
    data2 = []
    
    for i in entries:
        try:
            r = scrapeo_vuelo(path_carpeta + i)
            if r:
                data2 += r
                html_buenos += 1
            else:
                html_vacios += 1
        except:
            print("Fallo en url: {}".format(path_carpeta + i))

    print("Archviso html buenos: {}".format(html_buenos))
    print("--------------------------------------------")
    print("Archviso html malos: {}".format(html_vacios))
    
    columnas = ['aerolinea', 'horario_salida', 'terminal_salida', 'puerta_salida',\
                'horario_llegada', 'terminal_llegada', 'puerta_llegada', 'origen', 'destino']
    
    r = pd.DataFrame(data2, columns=columnas)
    r.to_pickle(path_carpeta + 'output.pkl')
    
    return r

# %% [markdown]
# ### Ejecución

# %%
scrapear_html_aviones('/Users/rodri/OneDrive/Documentos/html files 2/part2.tar/part2/')
# Out:
# Fallo en url: /Users/rodri/OneDrive/Documentos/html files 2/part2.tar/part2/output.pkl
# Archviso html buenos: 12980
# --------------------------------------------
# Archviso html malos: 7107
#                        aerolinea horario_salida terminal_salida puerta_salida  \
# 0         Mandarin    – AE 995            07:30               I            28
# 1         Mandarin    – AE 995            07:30               I             -
# 2        Mandarin    – AE 7931            12:30               D             -
# 3        Mandarin    – AE 7931            12:30               D             -
# 4        Mandarin    – AE 7931            12:30               D             -
# 5        Mandarin    – AE 7931            12:30               D             -
# 6         Mandarin    – AE 967            07:19               I            26
# 7        Mandarin    – AE 5103            19:20               I             -
# 8         Mandarin    – AE 764            09:00               -             -
# 9         Mandarin    – AE 766            11:40               -             -
# 10        Mandarin    – AE 768            15:00               -             -
# 11        Mandarin    – AE 770            17:10               -             -
# 12        Mandarin    – AE 764            09:00               -             -
# 13        Mandarin    – AE 766            11:40               -             -
# 14        Mandarin    – AE 768            15:00               -             -
# 15        Mandarin    – AE 770            17:10               -             -
# 16        Mandarin    – AE 764            09:00               -             -
# 17        Mandarin    – AE 766            11:40               -             -
# 18        Mandarin    – AE 768            15:00               -             -
# 19        Mandarin    – AE 770            17:10               -             -
