# %% [markdown]
# ### Links útiles

# %% [markdown]
# Skyscanner API documentation:
# - https://rapidapi.com/skyscanner/api/skyscanner-flight-search?endpoint=5aa1eab3e4b00687d3574279
# - https://skyscanner.github.io/slate/#api-documentation
#
# Unirest documentation for Python:
# - http://unirest.io/python.html

# %%
import pandas as pd
import numpy as np
import unirest
import datetime
import unicodedata

# %%
API_HOST = "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com"
API_KEY = "ec5cbd32b7mshbc3873e6092257dp11e806jsn09c588578b1f"

# %% [markdown]
# ## Intención de este notebook

# %% [markdown]
# Utilizar el archivo rutas.csv para matchear las rutas contenidas con la API de Skyscanner y de allí obtener todos los datos de cada vuelo. A saber:
# - Aerolinea
# - Ciudad origen
# - Ciudad destino
# - Fecha salida
# - Fecha llegada
# - Hora salida
# - Hora llegada
# - Cantidad de asientos disponibles (número aleatorio entre 0 y 5)
# - Costo

# %% [markdown]
# ### Archivo rutas.csv

# %%
rutas = pd.read_csv('../csv/rutas.csv', header = None)
rutas.columns = ['id','iata_origin','iata_destiny']

print(rutas.info())
rutas.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63330 entries, 0 to 63329
# Data columns (total 3 columns):
# id              63330 non-null object
# iata_origin     63330 non-null object
# iata_destiny    63330 non-null object
# dtypes: object(3)
# memory usage: 1.4+ MB
# None
#    id iata_origin iata_destiny
# 0  2B         ASF          KZN
# 1  2B         ASF          MRV
# 2  2B         CEK          KZN
# 3  2B         CEK          OVB
# 4  2B         DME          KZN

# %% [markdown]
# ### Funciones para obtener datos de vuelos de la API de Skyscanner

# %%
def create_session(iata_origin, iata_destiny, start_date):
    # Parametros obligatorios
    country = 'US'
    currency = 'USD'
    locale = 'en-US'
    origin = iata_origin + '-sky'
    destiny = iata_destiny + '-sky'
    departure = start_date
    adults = 1

    response = unirest.post("https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/pricing/v1.0",
      headers={
        "X-RapidAPI-Host": API_HOST,
        "X-RapidAPI-Key": API_KEY,
        "Content-Type": "application/x-www-form-urlencoded"
      },
      params={
        "country": country,
        "currency": currency,
        "locale": locale,
        "originPlace": origin,
        "destinationPlace": destiny,
        "outboundDate": start_date,
        "adults": 1
      }
    )
    
    return response

# %%
def poll_session_results(session_key):
    url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/pricing/uk2/v1.0/sessionkey?pageIndex=0&pageSize=1"
    current_url = url.replace('sessionkey', session_key)
    
    response = unirest.get(current_url, headers={"X-RapidAPI-Host": API_HOST, "X-RapidAPI-Key": API_KEY},
                          params={"sortType":'price'})
    
    return response

# %%
numb_days = 1
#start_date = 'anytime'

for i in range(1, numb_days+1):
    start_day = (datetime.datetime.today() + datetime.timedelta(days=i)).strftime('%Y-%m-%d')
    
    for index, row in rutas.head(1).iterrows():   
        response = create_session(row['iata_origin'], row['iata_destiny'], start_day)
        url = response.headers['Location'].split('/')
        session_key = url[len(url)-1]
        result = poll_session_results(session_key)

# %%
result.body
# Out:
# {u'Agents': [{u'Id': 4046777,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/websites/tlcy.png',
#    u'Name': u'Travelocity',
#    u'OptimisedForMobile': True,
#    u'Status': u'UpdatesComplete',
#    u'Type': u'TravelAgent'},
#   {u'Id': 2499060,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/websites/flot.png',
#    u'Name': u'Aeroflot',
#    u'OptimisedForMobile': True,
#    u'Status': u'UpdatesComplete',
#    u'Type': u'Airline'},
#   {u'Id': 3611253,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/websites/pobe.png',
#    u'Name': u'Pobeda',
#    u'OptimisedForMobile': True,
#    u'Status': u'UpdatesComplete',
#    u'Type': u'Airline'},
#   {u'Id': 2498533,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/websites/fldu.png',
#    u'Name': u'flydubai',
#    u'OptimisedForMobile': True,
#    u'Status': u'UpdatesComplete',
#    u'Type': u'Airline'},
#   {u'Id': 3934928,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/websites/skyp.png',
#    u'Name': u'Kiwi.com',
#    u'OptimisedForMobile': True,
#    u'Status': u'UpdatesComplete',
#    u'Type': u'TravelAgent'},
#   {u'Id': 2186003,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/websites/ctus.png',
#    u'Name': u'Cheaptickets',
#    u'OptimisedForMobile': True,
#    u'Status': u'UpdatesComplete',
#    u'Type': u'TravelAgent'},
#   {u'Id': 2407040,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/websites/etrp.png',
#    u'Name': u'Exploretrip',
#    u'OptimisedForMobile': False,
#    u'Status': u'UpdatesComplete',
#    u'Type': u'TravelAgent'},
#   {u'Id': 2043155,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/websites/bfus.png',
#    u'Name': u'Bravofly',
#    u'OptimisedForMobile': True,
#    u'Status': u'UpdatesComplete',
#    u'Type': u'TravelAgent'},
#   {u'Id': 3987731,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/websites/t2us.png',
#    u'Name': u'Travel2Be',
#    u'OptimisedForMobile': True,
#    u'Status': u'UpdatesComplete',
#    u'Type': u'TravelAgent'},
#   {u'Id': 2503955,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/websites/fnus.png',
#    u'Name': u'FlightNetwork',
#    u'OptimisedForMobile': True,
#    u'Status': u'UpdatesComplete',
#    u'Type': u'TravelAgent'},
#   {u'Id': 3507594,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/websites/orbz.png',
#    u'Name': u'Orbitz',
#    u'OptimisedForMobile': True,
#    u'Status': u'UpdatesComplete',
#    u'Type': u'TravelAgent'},
#   {u'Id': 2485523,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/websites/ffus.png',
#    u'Name': u'Flyfar',
#    u'OptimisedForMobile': True,
#    u'Status': u'UpdatesComplete',
#    u'Type': u'TravelAgent'},
#   {u'Id': 1960211,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/websites/arus.png',
#    u'Name': u'Mytrip',
#    u'OptimisedForMobile': True,
#    u'Status': u'UpdatesComplete',
#    u'Type': u'TravelAgent'},
#   {u'Id': 3038483,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/websites/kfus.png',
#    u'Name': u'Kissandfly',
#    u'OptimisedForMobile': False,
#    u'Status': u'UpdatesComplete',
#    u'Type': u'TravelAgent'},
#   {u'Id': 2628371,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/websites/gtus.png',
#    u'Name': u'GotoGate',
#    u'OptimisedForMobile': True,
#    u'Status': u'UpdatesComplete',
#    u'Type': u'TravelAgent'},
#   {u'Id': 3952406,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/websites/ssev.png',
#    u'Name': u'S7 Airlines',
#    u'OptimisedForMobile': True,
#    u'Status': u'UpdatesComplete',
#    u'Type': u'Airline'},
#   {u'Id': 2370323,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/websites/edus.png',
#    u'Name': u'eDreams',
#    u'OptimisedForMobile': True,
#    u'Status': u'UpdatesComplete',
#    u'Type': u'TravelAgent'},
#   {u'Id': 4243649,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/websites/vaya.png',
#    u'Name': u'vayama',
#    u'OptimisedForMobile': True,
#    u'Status': u'UpdatesComplete',
#    u'Type': u'TravelAgent'},
#   {u'Id': 4036115,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/websites/tgus.png',
#    u'Name': u'Travelgenio',
#    u'OptimisedForMobile': True,
#    u'Status': u'UpdatesComplete',
#    u'Type': u'TravelAgent'}],
#  u'Carriers': [{u'Code': u'SU',
#    u'DisplayCode': u'SU',
#    u'Id': 1717,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/airlines/SU.png',
#    u'Name': u'Aeroflot'},
#   {u'Code': u'FV',
#    u'DisplayCode': u'FV',
#    u'Id': 1094,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/airlines/FV.png',
#    u'Name': u'Rossiya Airlines'},
#   {u'Code': u'DP',
#    u'DisplayCode': u'DP',
#    u'Id': 1352,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/airlines/L8.png',
#    u'Name': u'Pobeda'},
#   {u'Code': u'UT',
#    u'DisplayCode': u'UT',
#    u'Id': 1812,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/airlines/UT.png',
#    u'Name': u'UTair'},
#   {u'Code': u'S7',
#    u'DisplayCode': u'S7',
#    u'Id': 1687,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/airlines/S7.png',
#    u'Name': u'S7 Airlines'},
#   {u'Code': u'B2',
#    u'DisplayCode': u'B2',
#    u'Id': 866,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/airlines/B2.png',
#    u'Name': u'Belavia'},
#   {u'Code': u'',
#    u'DisplayCode': u'EO',
#    u'Id': 265,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/airlines/default.png',
#    u'Name': u'Pegas Fly'},
#   {u'Code': u'N4',
#    u'DisplayCode': u'N4',
#    u'Id': 1479,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/airlines/NW.png',
#    u'Name': u'Nordwind Airlines'},
#   {u'Code': u'BT',
#    u'DisplayCode': u'BT',
#    u'Id': 900,
#    u'ImageUrl': u'https://s1.apideeplink.com/images/airlines/BT.png',
#    u'Name': u'airBaltic'}],
#  u'Currencies': [{u'Code': u'USD',
#    u'DecimalDigits': 2,
#    u'DecimalSeparator': u'.',
#    u'RoundingCoefficient': 0,
#    u'SpaceBetweenAmountAndSymbol': False,
#    u'Symbol': u'$',
#    u'SymbolOnLeft': True,
00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Inbound',
#    u'Duration': 865,
#    u'FlightNumbers': [{u'CarrierId': 1687, u'FlightNumber': u'1178'},
#     {u'CarrierId': 1687, u'FlightNumber': u'4437'},
#     {u'CarrierId': 866, u'FlightNumber': u'937'}],
#    u'Id': u'9565-1904281245--31913,-32511-2-13390-1904290210',
#    u'JourneyMode': u'Flight',
#    u'OperatingCarriers': [1687, 866],
#    u'OriginStation': 9565,
#    u'SegmentIds': [8, 9, 10],
#    u'Stops': [11051, 14347]},
#   {u'Arrival': u'2019-04-28T21:30:00',
#    u'Carriers': [1717, 1687],
#    u'Departure': u'2019-04-28T11:40:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Inbound',
#    u'Duration': 650,
#    u'FlightNumbers': [{u'CarrierId': 1717, u'FlightNumber': u'1643'},
#     {u'CarrierId': 1687, u'FlightNumber': u'63'}],
#    u'Id': u'9565-1904281140--32741,-31913-1-13390-1904282130',
#    u'JourneyMode': u'Flight',
#    u'OperatingCarriers': [1717, 1687],
#    u'OriginStation': 9565,
#    u'SegmentIds': [11, 12],
#    u'Stops': [16626, 11051]},
#   {u'Arrival': u'2019-04-28T21:30:00',
#    u'Carriers': [1687],
#    u'Departure': u'2019-04-28T17:50:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Inbound',
#    u'Duration': 280,
#    u'FlightNumbers': [{u'CarrierId': 1687, u'FlightNumber': u'63'},
#     {u'CarrierId': 1687, u'FlightNumber': u'1176'}],
#    u'Id': u'9565-1904281750--31913-1-13390-1904282130',
#    u'JourneyMode': u'Flight',
#    u'OperatingCarriers': [1687],
#    u'OriginStation': 9565,
#    u'SegmentIds': [13, 12],
#    u'Stops': [11051]},
#   {u'Arrival': u'2019-04-28T16:10:00',
#    u'Carriers': [1717, 1687],
#    u'Departure': u'2019-04-28T07:20:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Inbound',
#    u'Duration': 590,
#    u'FlightNumbers': [{u'CarrierId': 1717, u'FlightNumber': u'1173'},
#     {u'CarrierId': 1687, u'FlightNumber': u'65'}],
#    u'Id': u'9565-1904280720--32741,-31913-1-13390-1904281610',
#    u'JourneyMode': u'Flight',
#    u'OperatingCarriers': [1717, 1687],
#    u'OriginStation': 9565,
#    u'SegmentIds': [0, 14],
#    u'Stops': [16626, 11051]},
#   {u'Arrival': u'2019-04-28T19:10:00',
#    u'Carriers': [1687],
#    u'Departure': u'2019-04-28T12:45:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Inbound',
#    u'Duration': 445,
#    u'FlightNumbers': [{u'CarrierId': 1687, u'FlightNumber': u'1178'},
#     {u'CarrierId': 1687, u'FlightNumber': u'79'}],
#    u'Id': u'9565-1904281245--31913-1-13390-1904281910',
#    u'JourneyMode': u'Flight',
#    u'OperatingCarriers': [1687],
#    u'OriginStation': 9565,
#    u'SegmentIds': [8, 15],
#    u'Stops': [11051]},
#   {u'Arrival': u'2019-04-28T21:35:00',
#    u'Carriers': [1352, 1812],
#    u'Departure': u'2019-04-28T10:40:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Inbound',
#    u'Duration': 715,
#    u'FlightNumbers': [{u'CarrierId': 1352, u'FlightNumber': u'164'},
#     {u'CarrierId': 1812, u'FlightNumber': u'325'}],
#    u'Id': u'9565-1904281040--31436,-31717-1-13390-1904282135',
#    u'JourneyMode': u'Flight',
#    u'OperatingCarriers': [1352, 1812],
#    u'OriginStation': 9565,
#    u'SegmentIds': [6, 16],
#    u'Stops': [17538]},
#   {u'Arrival': u'2019-04-29T11:20:00',
#    u'Carriers': [1352],
#    u'Departure': u'2019-04-28T10:40:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Inbound',
#    u'Duration': 1540,
#    u'FlightNumbers': [{u'CarrierId': 1352, u'FlightNumber': u'164'},
#     {u'CarrierId': 1352, u'FlightNumber': u'283'}],
#    u'Id': u'9565-1904281040--31436-1-13390-1904291120',
#    u'JourneyMode': u'Flight',
#    u'OperatingCarriers': [1352],
#    u'OriginStation': 9565,
#    u'SegmentIds': [6, 17],
#    u'Stops': [17538]},
#   {u'Arrival': u'2019-04-28T17:45:00',
#    u'Carriers': [1717],
#    u'Departure': u'2019-04-28T11:40:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Inbound',
#    u'Duration': 425,
#    u'FlightNumbers': [{u'CarrierId': 1717, u'FlightNumber': u'1643'},
#     {u'CarrierId': 1717, u'FlightNumber': u'1192'}],
#    u'Id': u'9565-1904281140--32741-1-13390-1904281745',
#    u'JourneyMode': u'Flight',
#    u'OperatingCarriers': [1717],
#    u'OriginStation': 9565,
#    u'SegmentIds': [11, 18],
#    u'Stops': [16626]},
#   {u'Arrival': u'2019-04-29T01:40:00',
#    u'Carriers': [1687, 1717],
#    u'Departure': u'2019-04-28T17:50:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Inbound',
#    u'Duration': 530,
#    u'FlightNumbers': [{u'CarrierId': 1717, u'FlightNumber': u'6595'},
#     {u'CarrierId': 1687, u'FlightNumber': u'1176'},
#     {u'CarrierId': 1687, u'FlightNumber': u'41'}],
#    u'Id': u'9565-1904281750--31913,-32741-2-13390-1904290140',
#    u'JourneyMode': u'Flight',
#    u'OperatingCarriers': [1687, 1094],
#    u'OriginStation': 9565,
#    u'SegmentIds': [13, 19, 3],
#    u'Stops': [11051, 13489]},
#   {u'Arrival': u'2019-04-28T20:15:00',
#    u'Carriers': [1352],
#    u'Departure': u'2019-04-28T10:40:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Inbound',
#    u'Duration': 635,
#    u'FlightNumbers': [{u'CarrierId': 1352, u'FlightNumber': u'164'},
#     {u'CarrierId': 1352, u'FlightNumber': u'207'},
#     {u'CarrierId': 1352, u'FlightNumber': u'547'}],
#    u'Id': u'9565-1904281040--31436-2-13390-1904282015',
#    u'JourneyMode': u'Flight',
#    u'OperatingCarriers': [1352],
#    u'OriginStation': 9565,
#    u'SegmentIds': [6, 20, 21],
#    u'Stops': [17538, 13489]},
#   {u'Arrival': u'2019-04-29T01:40:00',
#    u'Carriers': [1717],
#    u'Departure': u'2019-04-28T11:40:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Inbound',
#    u'Duration': 900,
#    u'FlightNumbers': [{u'CarrierId': 1717, u'FlightNumber': u'6595'},
#     {u'CarrierId': 1717, u'FlightNumber': u'1643'},
#     {u'CarrierId': 1717, u'FlightNumber': u'22'}],
#    u'Id': u'9565-1904281140--32741-2-13390-1904290140',
#    u'JourneyMode': u'Flight',
#    u'OperatingCarriers': [1717, 1094],
#    u'OriginStation': 9565,
#    u'SegmentIds': [11, 22, 3],
#    u'Stops': [16626, 13489]},
#   {u'Arrival': u'2019-04-29T09:20:00',
#    u'Carriers': [1717, 1687],
#    u'Departure': u'2019-04-28T19:10:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Inbound',
#    u'Duration': 910,
#    u'FlightNumbers': [{u'CarrierId': 1717, u'FlightNumber': u'1175'},
#     {u'CarrierId': 1687, u'FlightNumber': u'61'}],
#    u'Id': u'9565-1904281910--32741,-31913-1-13390-1904290920',
#    u'JourneyMode': u'Flight',
#    u'OperatingCarriers': [1717, 1687],
#    u'OriginStation': 9565,
#    u'SegmentIds': [23, 24],
#    u'Stops': [16626, 11051]},
#   {u'Arrival': u'2019-04-29T01:20:00',
#    u'Carriers': [1717, 1479],
#    u'Departure': u'2019-04-28T19:10:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Inbound',
#    u'Duration': 430,
#    u'FlightNumbers': [{u'CarrierId': 1717, u'FlightNumber': u'1175'},
#     {u'CarrierId': 1479, u'FlightNumber': u'185'}],
#    u'Id': u'9565-1904281910--32741,-32021-1-13390-1904290120',
#    u'JourneyMode': u'Flight',
#    u'OperatingCarriers': [1717, 265],
#    u'OriginStation': 9565,
#    u'SegmentIds': [23, 25],
#    u'Stops': [16626]},
#   {u'Arrival': u'2019-04-28T21:30:00',
#    u'Carriers': [1687],
#    u'Departure': u'2019-04-28T12:45:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Inbound',
#    u'Duration': 585,
#    u'FlightNumbers': [{u'CarrierId': 1687, u'FlightNumber': u'1178'},
#     {u'CarrierId': 1687, u'FlightNumber': u'63'}],
#    u'Id': u'9565-1904281245--31913-1-13390-1904282130',
#    u'JourneyMode': u'Flight',
#    u'OperatingCarriers': [1687],
#    u'OriginStation': 9565,
#    u'SegmentIds': [8, 12],
#    u'Stops': [11051]},
#   {u'Arrival': u'2019-04-30T02:00:00',
#    u'Carriers': [1717, 900],
#    u'Departure': u'2019-04-28T19:10:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Inbound',
#    u'Duration': 1910,
#    u'FlightNumbers': [{u'CarrierId': 1717, u'FlightNumber': u'1175'},
#     {u'CarrierId': 1717, u'FlightNumber': u'2118'},
#     {u'CarrierId': 900, u'FlightNumber': u'450'}],
#    u'Id': u'9565-1904281910--32741,-32610-2-13390-1904300200',
#    u'JourneyMode': u'Flight',
#    u'OperatingCarriers': [1717, 900],
#    u'OriginStation': 9565,
#    u'SegmentIds': [23, 26, 27],
#    u'Stops': [16626, 15888]},
#   {u'Arrival': u'2019-04-28T23:50:00',
#    u'Carriers': [1717],
#    u'Departure': u'2019-04-28T19:10:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Inbound',
#    u'Duration': 340,
#    u'FlightNumbers': [{u'CarrierId': 1717, u'FlightNumber': u'1175'},
#     {u'CarrierId': 1717, u'FlightNumber': u'1198'}],
#    u'Id': u'9565-1904281910--32741-1-13390-1904282350',
#    u'JourneyMode': u'Flight',
#    u'OperatingCarriers': [1717],
#    u'OriginStation': 9565,
#    u'SegmentIds': [23, 28],
#    u'Stops': [16626]}],
#  u'Places': [{u'Code': u'KZN',
#    u'Id': 3969,
#    u'Name': u'Kazan',
#    u'ParentId': 191,
#    u'Type': u'City'},
#   {u'Code': u'VKO',
#    u'Id': 17538,
#    u'Name': u'Moscow Vnukovo',
#    u'ParentId': 5227,
#    u'Type': u'Airport'},
#   {u'Code': u'MSQ',
#    u'Id': 5319,
#    u'Name': u'Minsk',
#    u'ParentId': 248,
#    u'Type': u'City'},
#   {u'Code': u'MOW',
#    u'Id': 5227,
#    u'Name': u'Moscow',
#    u'ParentId': 191,
#    u'Type': u'City'},
#   {u'Code': u'DME',
#    u'Id': 11051,
#    u'Name': u'Moscow Domodedovo',
#    u'ParentId': 5227,
#    u'Type': u'Airport'},
#   {u'Code': u'MSQ',
#    u'Id': 14347,
#    u'Name': u'Minsk International 2',
#    u'ParentId': 5319,
#    u'Type': u'Airport'},
#   {u'Code': u'KZN',
#    u'Id': 13390,
#    u'Name': u'Kazan',
#    u'ParentId': 3969,
#    u'Type': u'Airport'},
#   {u'Code': u'LV', u'Id': 238, u'Name': u'Latvia', u'Type': u'Country'},
#   {u'Code': u'RIX',
#    u'Id': 15888,
#    u'Name': u'Riga International',
#    u'ParentId': 6713,
#    u'Type': u'Airport'},
#   {u'Code': u'LED',
#    u'Id': 13489,
#    u'Name': u'St Petersburg Pulkovo',
#    u'ParentId': 6171,
#    u'Type': u'Airport'},
#   {u'Code': u'SVO',
#    u'Id': 16626,
#    u'Name': u'Moscow Sheremetyevo',
#    u'ParentId': 5227,
#    u'Type': u'Airport'},
#   {u'Code': u'BY', u'Id': 248, u'Name': u'Belarus', u'Type': u'Country'},
#   {u'Code': u'RIX',
#    u'Id': 6713,
#    u'Name': u'Riga',
#    u'ParentId': 238,
#    u'Type': u'City'},
#   {u'Code': u'ASF',
#    u'Id': 635,
#    u'Name': u'Astrakhan',
#    u'ParentId': 191,
#    u'Type': u'City'},
#   {u'Code': u'LED',
#    u'Id': 6171,
#    u'Name': u'St Petersburg',
#    u'ParentId': 191,
#    u'Type': u'City'},
#   {u'Code': u'ASF',
#    u'Id': 9565,
#    u'Name': u'Astrakhan',
#    u'ParentId': 635,
#    u'Type': u'Airport'},
#   {u'Code': u'RU', u'Id': 191, u'Name': u'Russia', u'Type': u'Country'}],
#  u'Query': {u'Adults': 1,
#   u'CabinClass': u'economy',
#   u'Children': 0,
#   u'Country': u'US',
#   u'Currency': u'USD',
#   u'DestinationPlace': u'13390',
#   u'GroupPricing': False,
#   u'Infants': 0,
#   u'Locale': u'en-US',
#   u'LocationSchema': u'Default',
#   u'OriginPlace': u'9565',
#   u'OutboundDate': u'2019-04-28'},
#  u'Segments': [{u'ArrivalDateTime': u'2019-04-28T08:40:00',
#    u'Carrier': 1717,
#    u'DepartureDateTime': u'2019-04-28T07:20:00',
#    u'DestinationStation': 16626,
#    u'Directionality': u'Outbound',
#    u'Duration': 140,
#    u'FlightNumber': u'1173',
#    u'Id': 0,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1717,
#    u'OriginStation': 9565},
#   {u'ArrivalDateTime': u'2019-04-28T12:40:00',
#    u'Carrier': 1717,
#    u'DepartureDateTime': u'2019-04-28T11:05:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Outbound',
#    u'Duration': 95,
#    u'FlightNumber': u'1276',
#    u'Id': 1,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1717,
#    u'OriginStation': 16626},
#   {u'ArrivalDateTime': u'2019-04-28T19:45:00',
#    u'Carrier': 1717,
#    u'DepartureDateTime': u'2019-04-28T18:15:00',
#    u'DestinationStation': 13489,
#    u'Directionality': u'Outbound',
#    u'Duration': 90,
#    u'FlightNumber': u'26',
#    u'Id': 2,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1717,
#    u'OriginStation': 16626},
#   {u'ArrivalDateTime': u'2019-04-29T01:40:00',
#    u'Carrier': 1717,
#    u'DepartureDateTime': u'2019-04-28T23:35:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Outbound',
#    u'Duration': 125,
#    u'FlightNumber': u'6595',
#    u'Id': 3,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1094,
#    u'OriginStation': 13489},
#   {u'ArrivalDateTime': u'2019-04-29T08:25:00',
#    u'Carrier': 1717,
#    u'DepartureDateTime': u'2019-04-29T07:00:00',
#    u'DestinationStation': 13489,
#    u'Directionality': u'Outbound',
#    u'Duration': 85,
#    u'FlightNumber': u'6022',
#    u'Id': 4,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1094,
#    u'OriginStation': 17538},
#   {u'ArrivalDateTime': u'2019-04-30T01:40:00',
#    u'Carrier': 1717,
#    u'DepartureDateTime': u'2019-04-29T23:35:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Outbound',
#    u'Duration': 125,
#    u'FlightNumber': u'6595',
#    u'Id': 5,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1094,
#    u'OriginStation': 13489},
#   {u'ArrivalDateTime': u'2019-04-28T11:55:00',
#    u'Carrier': 1352,
#    u'DepartureDateTime': u'2019-04-28T10:40:00',
#    u'DestinationStation': 17538,
#    u'Directionality': u'Outbound',
#    u'Duration': 135,
#    u'FlightNumber': u'164',
#    u'Id': 6,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1352,
#    u'OriginStation': 9565},
#   {u'ArrivalDateTime': u'2019-04-29T04:10:00',
#    u'Carrier': 1812,
#    u'DepartureDateTime': u'2019-04-29T02:40:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Outbound',
#    u'Duration': 90,
#    u'FlightNumber': u'343',
#    u'Id': 7,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1812,
#    u'OriginStation': 17538},
#   {u'ArrivalDateTime': u'2019-04-28T14:00:00',
#    u'Carrier': 1687,
#    u'DepartureDateTime': u'2019-04-28T12:45:00',
#    u'DestinationStation': 11051,
#    u'Directionality': u'Outbound',
#    u'Duration': 135,
#    u'FlightNumber': u'1178',
#    u'Id': 8,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1687,
#    u'OriginStation': 9565},
#   {u'ArrivalDateTime': u'2019-04-28T21:10:00',
#    u'Carrier': 1687,
#    u'DepartureDateTime': u'2019-04-28T19:50:00',
#    u'DestinationStation': 14347,
#    u'Directionality': u'Outbound',
#    u'Duration': 80,
#    u'FlightNumber': u'4437',
#    u'Id': 9,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 866,
#    u'OriginStation': 11051},
#   {u'ArrivalDateTime': u'2019-04-29T02:10:00',
#    u'Carrier': 866,
#    u'DepartureDateTime': u'2019-04-28T23:50:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Outbound',
#    u'Duration': 140,
#    u'FlightNumber': u'937',
#    u'Id': 10,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 866,
#    u'OriginStation': 14347},
#   {u'ArrivalDateTime': u'2019-04-28T13:00:00',
#    u'Carrier': 1717,
#    u'DepartureDateTime': u'2019-04-28T11:40:00',
#    u'DestinationStation': 16626,
#    u'Directionality': u'Outbound',
#    u'Duration': 140,
#    u'FlightNumber': u'1643',
#    u'Id': 11,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1717,
#    u'OriginStation': 9565},
#   {u'ArrivalDateTime': u'2019-04-28T21:30:00',
#    u'Carrier': 1687,
#    u'DepartureDateTime': u'2019-04-28T19:55:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Outbound',
#    u'Duration': 95,
#    u'FlightNumber': u'63',
#    u'Id': 12,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1687,
#    u'OriginStation': 11051},
#   {u'ArrivalDateTime': u'2019-04-28T19:05:00',
#    u'Carrier': 1687,
#    u'DepartureDateTime': u'2019-04-28T17:50:00',
#    u'DestinationStation': 11051,
#    u'Directionality': u'Outbound',
#    u'Duration': 135,
#    u'FlightNumber': u'1176',
#    u'Id': 13,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1687,
#    u'OriginStation': 9565},
#   {u'ArrivalDateTime': u'2019-04-28T16:10:00',
#    u'Carrier': 1687,
#    u'DepartureDateTime': u'2019-04-28T14:40:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Outbound',
#    u'Duration': 90,
#    u'FlightNumber': u'65',
#    u'Id': 14,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1687,
#    u'OriginStation': 11051},
#   {u'ArrivalDateTime': u'2019-04-28T19:10:00',
#    u'Carrier': 1687,
#    u'DepartureDateTime': u'2019-04-28T17:35:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Outbound',
#    u'Duration': 95,
#    u'FlightNumber': u'79',
#    u'Id': 15,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1687,
#    u'OriginStation': 11051},
#   {u'ArrivalDateTime': u'2019-04-28T21:35:00',
#    u'Carrier': 1812,
#    u'DepartureDateTime': u'2019-04-28T20:10:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Outbound',
#    u'Duration': 85,
#    u'FlightNumber': u'325',
#    u'Id': 16,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1812,
#    u'OriginStation': 17538},
#   {u'ArrivalDateTime': u'2019-04-29T11:20:00',
#    u'Carrier': 1352,
#    u'DepartureDateTime': u'2019-04-29T09:50:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Outbound',
#    u'Duration': 90,
#    u'FlightNumber': u'283',
#    u'Id': 17,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1352,
#    u'OriginStation': 17538},
#   {u'ArrivalDateTime': u'2019-04-28T17:45:00',
#    u'Carrier': 1717,
#    u'DepartureDateTime': u'2019-04-28T16:00:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Outbound',
#    u'Duration': 105,
#    u'FlightNumber': u'1192',
#    u'Id': 18,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1717,
#    u'OriginStation': 16626},
#   {u'ArrivalDateTime': u'2019-04-28T22:05:00',
#    u'Carrier': 1687,
#    u'DepartureDateTime': u'2019-04-28T20:30:00',
#    u'DestinationStation': 13489,
#    u'Directionality': u'Outbound',
#    u'Duration': 95,
#    u'FlightNumber': u'41',
#    u'Id': 19,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1687,
#    u'OriginStation': 11051},
#   {u'ArrivalDateTime': u'2019-04-28T15:55:00',
#    u'Carrier': 1352,
#    u'DepartureDateTime': u'2019-04-28T14:25:00',
#    u'DestinationStation': 13489,
#    u'Directionality': u'Outbound',
#    u'Duration': 90,
#    u'FlightNumber': u'207',
#    u'Id': 20,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1352,
#    u'OriginStation': 17538},
#   {u'ArrivalDateTime': u'2019-04-28T20:15:00',
#    u'Carrier': 1352,
#    u'DepartureDateTime': u'2019-04-28T17:55:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Outbound',
#    u'Duration': 140,
#    u'FlightNumber': u'547',
#    u'Id': 21,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1352,
#    u'OriginStation': 13489},
#   {u'ArrivalDateTime': u'2019-04-28T16:45:00',
#    u'Carrier': 1717,
#    u'DepartureDateTime': u'2019-04-28T15:20:00',
#    u'DestinationStation': 13489,
#    u'Directionality': u'Outbound',
#    u'Duration': 85,
#    u'FlightNumber': u'22',
#    u'Id': 22,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1717,
#    u'OriginStation': 16626},
#   {u'ArrivalDateTime': u'2019-04-28T20:30:00',
#    u'Carrier': 1717,
#    u'DepartureDateTime': u'2019-04-28T19:10:00',
#    u'DestinationStation': 16626,
#    u'Directionality': u'Outbound',
#    u'Duration': 140,
#    u'FlightNumber': u'1175',
#    u'Id': 23,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1717,
#    u'OriginStation': 9565},
#   {u'ArrivalDateTime': u'2019-04-29T09:20:00',
#    u'Carrier': 1687,
#    u'DepartureDateTime': u'2019-04-29T07:45:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Outbound',
#    u'Duration': 95,
#    u'FlightNumber': u'61',
#    u'Id': 24,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1687,
#    u'OriginStation': 11051},
#   {u'ArrivalDateTime': u'2019-04-29T01:20:00',
#    u'Carrier': 1479,
#    u'DepartureDateTime': u'2019-04-28T23:45:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Outbound',
#    u'Duration': 95,
#    u'FlightNumber': u'185',
#    u'Id': 25,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 265,
#    u'OriginStation': 16626},
#   {u'ArrivalDateTime': u'2019-04-29T00:45:00',
#    u'Carrier': 1717,
#    u'DepartureDateTime': u'2019-04-28T22:55:00',
#    u'DestinationStation': 15888,
#    u'Directionality': u'Outbound',
#    u'Duration': 110,
#    u'FlightNumber': u'2118',
#    u'Id': 26,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1717,
#    u'OriginStation': 16626},
#   {u'ArrivalDateTime': u'2019-04-30T02:00:00',
#    u'Carrier': 900,
#    u'DepartureDateTime': u'2019-04-29T23:35:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Outbound',
#    u'Duration': 145,
#    u'FlightNumber': u'450',
#    u'Id': 27,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 900,
#    u'OriginStation': 15888},
#   {u'ArrivalDateTime': u'2019-04-28T23:50:00',
#    u'Carrier': 1717,
#    u'DepartureDateTime': u'2019-04-28T22:15:00',
#    u'DestinationStation': 13390,
#    u'Directionality': u'Outbound',
#    u'Duration': 95,
#    u'FlightNumber': u'1198',
#    u'Id': 28,
#    u'JourneyMode': u'Flight',
#    u'OperatingCarrier': 1717,
#    u'OriginStation': 16626}],
#  u'SessionKey': u'7add6878-e888-4683-8dc2-980044aade02',
#  u'Status': u'UpdatesComplete'}

# %%
def browse_flight_prices(flight_query, iata_origin, iata_destiny, start_date):
    # query = (quotes, routes, dates)
    query = flight_query

    # Parametros obligatorios
    country = 'US'
    currency = 'USD'
    locale = 'en-US'
    origin = iata_origin + '-sky'
    destiny = iata_destiny + '-sky'
    departure = start_date

    # Parametros optativos
    arrival = ''

    url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browsequery/v1.0/country/currency/locale/origin/destiny/departure?inboundpartialdate=arrival"

    current_url = url.replace('query', query)\
                     .replace('country', country)\
                     .replace('currency', currency)\
                     .replace('locale', locale)\
                     .replace('origin', origin)\
                     .replace('destiny', destiny)\
                     .replace('departure', departure)\
                     .replace('arrival', arrival)

    response = unirest.get(current_url, headers={"X-RapidAPI-Host": API_HOST, "X-RapidAPI-Key": API_KEY})
    
    return response.body

# %% [markdown]
# ### Creo el dataframe con toda la info de los vuelos

# %%
info_vuelos = pd.DataFrame(columns=['airline', 'origin', 'destiny', 'departure_date',\
                                    'arrival_date', 'cost', 'available_sits'])

# TO DO: ver como appendear una lista de valores al df

numb_days = 10
query = 'quotes'
#start_date = 'anytime'

response_example = ''

for i in range(1, numb_days+1):
    start_day = (datetime.datetime.today() + datetime.timedelta(days=i)).strftime('%Y-%m-%d')
    
    for index, row in rutas.head(2).iterrows():   
        response = browse_flight_prices(query, row['iata_origin'], row['iata_destiny'], start_day)
        if response['Quotes']:
            response_example = response
            break
    
    if response_example:
        break

# %%
response_example
# Out:
# {u'Carriers': [{u'CarrierId': 1352, u'Name': u'Pobeda'},
#   {u'CarrierId': 1687, u'Name': u'S7 Airlines'},
#   {u'CarrierId': 1717, u'Name': u'Aeroflot'}],
#  u'Currencies': [{u'Code': u'USD',
#    u'DecimalDigits': 2,
#    u'DecimalSeparator': u'.',
#    u'RoundingCoefficient': 0,
#    u'SpaceBetweenAmountAndSymbol': False,
#    u'Symbol': u'$',
#    u'SymbolOnLeft': True,
#    u'ThousandsSeparator': u','}],
#  u'Places': [{u'CityId': u'ASTR',
#    u'CityName': u'Astrakhan',
#    u'CountryName': u'Russia',
#    u'IataCode': u'ASF',
#    u'Name': u'Astrakhan',
#    u'PlaceId': 40870,
#    u'SkyscannerCode': u'ASF',
#    u'Type': u'Station'},
#   {u'CityId': u'KAZA',
#    u'CityName': u'Kazan',
#    u'CountryName': u'Russia',
#    u'IataCode': u'KZN',
#    u'Name': u'Kazan',
#    u'PlaceId': 64254,
#    u'SkyscannerCode': u'KZN',
#    u'Type': u'Station'}],
#  u'Quotes': [{u'Direct': False,
#    u'MinPrice': 159.0,
#    u'OutboundLeg': {u'CarrierIds': [1717],
#     u'DepartureDate': u'2019-04-27T00:00:00',
#     u'DestinationId': 64254,
#     u'OriginId': 40870},
#    u'QuoteDateTime': u'2019-04-26T14:42:00',
#    u'QuoteId': 1}]}

# %%
def normalizar(unicode_string):
    string = unicodedata.normalize('NFKD', unicode_string).encode('ascii', 'ignore')
    return string

# %%
# TODO: falta la duracion, no esta en este endpoint
airline = normalizar(response_example['Carriers'][0]['Name'])
origin = normalizar(response_example['Places'][0]['CityName'])
destiny = normalizar(response_example['Places'][1]['CityName'])
departure_date = normalizar(response_example['Quotes'][0]['OutboundLeg']['DepartureDate'])
#arrival_date = ???
cost = response_example['Quotes'][0]['MinPrice']
available_sits = np.random.randint(0, 5) # (0, 5, info_vuelos.shape[0])
# Out:
# 4

# %% [markdown]
# ### Exporto el dataframe completo a csv para luego cargarlo en Neo4j

# %%
info_vuelos.to_csv('csv/info_vuelos_completa.csv', index = None, header = True)
